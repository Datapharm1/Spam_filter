# %%
#importing libraries
import pandas as pd
import numpy as np

# %%
# reading the dataset into a dataframe
df= pd.read_csv('spam.csv')
df

# %%
#checking the number of rows and columns
df.shape
# Out:
# (5572, 2)

# %%
#droping possible duplicates
df.drop_duplicates(inplace = True)

# %%
#checking the number of rows and columns
df.shape
# Out:
# (5157, 2)

# %%
#checking for nulls
df.isnull().sum()
# Out:
# Category    0
# Message     0
# dtype: int64

# %%
#checking for the unique values in the category columns
df['Category'].unique()
# Out:
# array(['ham', 'spam'], dtype=object)

# %%
#converting the numeric- spam = 1 and ham = 0
df['Category'] = df['Category'].apply(lambda x: 1 if x == 'spam' else 0)

# %%
df['Category'].unique()
# Out:
# array([0, 1])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5157 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  5157 non-null   int64
#  1   Message   5157 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 120.9+ KB

# %%
# defining x and y
x = df['Message']
y= df['Category']

# %%
#importing machine learning packages
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

# %%
#spliting our data into train and test data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
#converting the x_train into numeric using count vectorizer
cv= CountVectorizer(stop_words = 'english')
x_train_count = cv.fit_transform(x_train)

# %%
#creating and training the model
model = MultinomialNB()
model.fit(x_train_count, y_train)
# Out:
# MultinomialNB()

# %%
#pretesting the model
spam = ['Congratulations!, winner of the cash']
spam_count = cv.transform(spam)
model.predict(spam_count)
# Out:
# array([1])

# %%
# pretesing
ham = ['I love you']
ham_count = cv.transform(ham)
model.predict(ham_count)
# Out:
# array([0])

# %%
#Testing the model

#transform x_test
x_test_count = cv.transform(x_test)

#testing the model proper
model.score(x_test_count, y_test) #returns the mean accuracy on the given test data and labels
# Out:
# 0.9854651162790697

# %%
# predicting message
def predict(message):
    input_message = cv.transform([message]).toarray()
    result = model.predict(input_message)
    print(result)
predict('Congratulations!, winner of the cash')
# Out:
# [1]

# %%
# Building web applicatio
import streamlit as st

# %%
# !jupyter nbconvert --to script Spam_filter.ipynb
# Out:
# [NbConvertApp] Converting notebook Spam_filter.ipynb to script
# [NbConvertApp] Writing 2235 bytes to Spam_filter.py

# %%
# Out:
# ^C
